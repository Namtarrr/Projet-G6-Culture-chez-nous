# %%
import cx_Oracle
import os


# Chemin du répertoire contenant le client Oracle
oracle_client_path : str = r"C:\Users\noebo\Documents\4MASTER\projet\insert\instantclient_23_6"

# Récupérer la valeur actuelle de la variable PATH
current_path : str = os.environ.get("PATH", "")

# Ajouter le chemin du client Oracle à la variable PATH
new_path : str = f"{current_path};{oracle_client_path}"

# Définir la nouvelle valeur de la variable PATH
os.environ["PATH"] = new_path

# Vérifier si le chemin a été ajouté correctement
print("Nouvelle valeur de PATH :", os.environ.get("PATH"))
# Out:
# Nouvelle valeur de PATH : c:\Users\noebo\AppData\Local\Programs\Python\Python39;c:\Users\noebo\AppData\Roaming\Python\Python39\Scripts;C:\Program Files (x86)\Common Files\Oracle\Java\javapath;C:\windows\system32;C:\windows;C:\windows\System32\Wbem;C:\windows\System32\WindowsPowerShell\v1.0\;C:\windows\System32\OpenSSH\;C:\Program Files (x86)\NVIDIA Corporation\PhysX\Common;C:\Program Files\NVIDIA Corporation\NVIDIA NvDLISR;C:\Program Files (x86)\Pulse Secure\VC142.CRT\X64\;C:\Program Files (x86)\Pulse Secure\VC142.CRT\X86\;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0\;C:\WINDOWS\System32\OpenSSH\;D:\git\Git\cmd;C:\Program Files\nodejs\;C:\Program Files\Docker\Docker\resources\bin;C:\Program Files\dotnet\;D:\anaconda;D:\anaconda\Library\mingw-w64\bin;D:\anaconda\Library\usr\bin;D:\anaconda\Library\bin;D:\anaconda\Scripts;C:\Users\noebo\AppData\Local\Microsoft\WindowsApps;C:\Users\noebo\AppData\Local\GitHubDesktop\bin;C:\Users\noebo
# ...

# %%
#fichier CSV permettant de corriger certain code postaux
import pandas as pd

# Lire le fichier CSV
df = pd.read_csv("./ins.csv",sep=';' )

# %% [markdown]
# insert bibliotheque.csv

# %%
import csv
utilisateur :str = ""
mot_de_passe : str = ""
adresse_IP : str = ""
port : int  = 1521
sid : str = ""

dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
cursor = connection.cursor()
i : int = 0
v : int = 0
except1 : list = []
except2 : list = []

with open('./BIBLIO.csv', 'r', encoding='utf-8') as fichier:
    for ligne in fichier:
                
        ligne = ligne.replace("'"," ").replace("[","").replace("]", "").replace("\"", "")
        lignetab = ligne.strip().split(',')
        if len(lignetab[0]) < 5 :
            lignetab[0] = '0'+lignetab[0] 
        Cligne = 'insert into bibliotheque values (\'' + lignetab[0] + '\', NULL,\'' + lignetab[1] +'\',\'' + lignetab[2] + '\',' + lignetab[3] + ',\'' + lignetab[4] + '\',\'' + "Bibliotheque" + '\',' + "NULL" + ',' + "NULL" + ',' + lignetab[7] + ',' + lignetab[6] + ',' + lignetab[5] + ',' +  lignetab[8] + ',' + lignetab[9] + ')'
        if type(lignetab[5]) == str :
            try :
                float(lignetab[5])
            except :
                print(lignetab[5])
                print(Cligne)                
            v = v+1
            try :    
                cursor.execute(Cligne)
            except :
                print("bad")
                except1.append(Cligne)
            if (v == 2000):
                connection.commit()
                cursor.close()
                connection.close()
                dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
                connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
                cursor = connection.cursor()
                v = 0
                print(i)
        i = i + 1
connection.commit()
cursor.close()
connection.close()

# %% [markdown]
# insert in departement.csv

# %%
import csv
utilisateur :str = ""
mot_de_passe : str = ""
adresse_IP : str = ""
port : int  = 1521
sid : str = ""

dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
cursor = connection.cursor()
i : int = 0
v : int = 0
except1 : list = []
except2 : list = []

with open('./dep.csv', 'r', encoding='utf-8') as fichier:
    for ligne in fichier:
        if i > 0 :
            ligne = ligne.replace("'"," ").replace("[","").replace("]", "").replace("\"", "")
            lignetab = ligne.strip().split(',')
            listcp = lignetab[0].split('/')
            for cp in listcp :
                if lignetab[2]=='97' :
                    Cligne = 'insert into departement values (\'' + cp[:3] + '\',\'' + lignetab[1].strip() + '\',\'' + cp + '\')'
                else :    
                    Cligne = 'insert into departement values (\'' + lignetab[2] + '\',\'' + lignetab[1].strip() + '\',\'' + cp + '\')'
                print(Cligne)
                v = v+1
                try :    
                    cursor.execute(Cligne)
                except :
                    print("bad")
                    except1.append(Cligne)
            
                if (v == 2000):
                        connection.commit()
                        cursor.close()
                        connection.close()
                        dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
                        connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
                        cursor = connection.cursor()
                        v = 0
                        print(i)
        i = i + 1
connection.commit()
cursor.close()
connection.close()

# %% [markdown]
# insert de commune .csv

# %%
import csv
utilisateur :str = ""
mot_de_passe : str = ""
adresse_IP : str = ""
port : int  = 1521
sid : str = ""

dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
cursor = connection.cursor()
i : int = 0
v : int = 0
except1 : list = []
except2 : list = []
#on a juste de changer le nom du fichier pour un ajouter un nouveau
with open('./OKOKCOMMUNE.csv', 'r', encoding='utf-8') as fichier:
    for ligne in fichier :
        if i > 0 :
            ligne = ligne.replace("'"," ")
            lignetab = ligne.strip().split(',')
            '''ndep commune revenu cp pop'''
            ''' commune cp pop revenu'''
            Cligne = 'insert into COMMUNE values (\'' + lignetab[1] + '\',\'' + lignetab[3] + '\',' + lignetab[4] + ',' + lignetab[2] + ')'
            print(Cligne)
            v = v+1
            try :    
                cursor.execute(Cligne)
            except :
                print("bad")
                except1.append(Cligne)
        
            if (v == 2000):
                    connection.commit()
                    cursor.close()
                    connection.close()
                    dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
                    connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
                    cursor = connection.cursor()
                    v = 0
                    print(i)
        i = i + 1
connection.commit()
cursor.close()
connection.close()

# %% [markdown]
# Insertion du fichier qui contient les dépenses des départements

# %%
import csv
utilisateur :str = ""
mot_de_passe : str = ""
adresse_IP : str = ""
port : int  = 1521
sid : str = ""

dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
cursor = connection.cursor()
i : int = 0
v : int = 0
except1 : list = []
except2 : list = []
#on a juste de changer le nom du fichier pour un ajouter un nouveau
with open('./depCult.csv', 'r', encoding='utf-8') as fichier:
    for ligne in fichier :
        if i > 0 :
            ligne = ligne.replace("'"," ")
            lignetab = ligne.strip().split(',')
            cligne = 'update departement set DEPENSES_TOT='+ lignetab[3] + ', DEPENSES_TOT_HAB=' + lignetab[4] + ',EFFORT_BUDGET_TOT=' + lignetab[5]  +' where upper("nomdept")=upper(\''+lignetab[2]+'\')'
            print(cligne)            
        
            v = v+1
            try :    
                cursor.execute(cligne)
            except :
                print("bad")
                except1.append(cligne)
        
            if (v == 2000):
                    connection.commit()
                    cursor.close()
                    connection.close()
                    dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
                    connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
                    cursor = connection.cursor()
                    v = 0
                    print(i)
        i = i + 1
connection.commit()
cursor.close()
connection.close()
# Out:
# update departement set DEPENSES_TOT=2817942, DEPENSES_TOT_HAB=19,EFFORT_BUDGET_TOT=1.4 where upper("nomdept")=upper('HAUTES-ALPES')
# update departement set DEPENSES_TOT=8159803, DEPENSES_TOT_HAB=21,EFFORT_BUDGET_TOT=1.5 where upper("nomdept")=upper('AUDE')
# update departement set DEPENSES_TOT=20403142, DEPENSES_TOT_HAB=10,EFFORT_BUDGET_TOT=0.7 where upper("nomdept")=upper('BOUCHES-DU-RHONE')
# update departement set DEPENSES_TOT=10958562, DEPENSES_TOT_HAB=17,EFFORT_BUDGET_TOT=1.5 where upper("nomdept")=upper('CHARENTE-MARITIME')
# update departement set DEPENSES_TOT=5538102, DEPENSES_TOT_HAB=22,EFFORT_BUDGET_TOT=2.0 where upper("nomdept")=upper('CORREZE')
# update departement set DEPENSES_TOT=2919777, DEPENSES_TOT_HAB=7,EFFORT_BUDGET_TOT=0.7 where upper("nomdept")=upper('EURE-ET-LOIR')
# update departement set DEPENSES_TOT=18051215, DEPENSES_TOT_HAB=19,EFFORT_BUDGET_TOT=2.2 where upper("nomdept")=upper('FINISTERE')
# ...

# %% [markdown]
# insert dans batiment momument

# %%
import csv
utilisateur :str = ""
mot_de_passe : str = ""
adresse_IP : str = ""
port : int  = 1521
sid : str = ""

dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
cursor = connection.cursor()
i : int = 0
v : int = 0
except1 : list = []
except2 : list = []
#on a juste de changer le nom du fichier pour un ajouter un nouveau
with open('./data_batmon2.csv', 'r', encoding='utf-8') as fichier:
    for ligne in fichier :
        if i > 0 :
            ligne = ligne.replace("'"," ")
            lignetab = ligne.strip().split(',')
            if len(lignetab)==9 :
                Cligne = 'insert into batiment_monument values (\'' + lignetab[4] + '\',\'' + lignetab[3] + '\',\'' + lignetab[5].replace("&", "'||'&'||'") + '\',\'' + lignetab[1] + '\',\'' + lignetab[0] + '\',' + "NULL" + ",NULL," + lignetab[6] + ',' + lignetab[7]  + ')'
            else :
                Cligne = 'insert into batiment_monument values (\'' + lignetab[4] + '\',\'' + lignetab[3] + '\',\'' + lignetab[4].replace("&", "'||'&'||'") + '\',\'' + lignetab[1] + '\',\'' + lignetab[0] + '\',' + "NULL" + ",NULL," + lignetab[5] + ',' + lignetab[6]  + ')'
            print(Cligne)
            try :    
                cursor.execute(Cligne)
            except :
                print("bad")
                except1.append(Cligne)
            v = v+1
                    
            if (v == 2000):
                    connection.commit()
                    cursor.close()
                    connection.close()
                    dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
                    connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
                    cursor = connection.cursor()
                    v = 0
                    print(i)
        i = i + 1
connection.commit()
cursor.close()
connection.close()

# %% [markdown]
# Insert festivals.csv

# %%
import csv
utilisateur :str = ""
mot_de_passe : str = ""
adresse_IP : str = ""
port : int  = 1521
sid : str = ""

dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
cursor = connection.cursor()
i : int = 0
v : int = 0
except1 : list = []
except2 : list = []
#on a juste de changer le nom du fichier pour un ajouter un nouveau
with open('./OKOK_festivals-global-festivals.csv', 'r', encoding='utf-8') as fichier:
    for ligne in fichier:
        if i > 0 :
            ligne = ligne.replace("'"," ").replace("[","").replace("]", "").replace("\"", "")
            lignetab = ligne.strip().split(',')
            cp = lignetab[1]
            print(cp)
            codepo = df[df["Commune"].str.upper() == lignetab[2].upper().replace("_"," ")]["Code Postal"]
            if codepo.empty == False:
                cp = codepo.iloc[0]
                print("ty")
            elif df[df["Code INSEE"].str.upper() == lignetab[1]]["Code Postal"].empty == False :
                cp = df[df["Code INSEE"].str.upper() == lignetab[1]]["Code Postal"].iloc[0]
                print("1")
            elif df[df["Code Postal"].str.upper() == lignetab[1]]["Code Postal"].empty == False :
                cp=df[df["Code Postal"].str.upper() == lignetab[1]]["Code Postal"].iloc[0]
                print("2")
            elif lignetab[1].startswith("75"):
                cp = '75001'
                print("3")
            elif lignetab[1].startswith("976"):
                cp = '97680'
            elif lignetab[1].startswith("971"):
                cp = '97116'     
            elif lignetab[1].startswith("972"):
                cp = '97660' 
            elif lignetab[1].startswith("973"):
                cp = '97311'  
            elif lignetab[1].startswith("974"):
                cp = '97427'   
            elif lignetab[1].startswith("987"):
                cp = '98735'
            elif lignetab[1].startswith("975"):
                cp = '97502'
            elif lignetab[1].startswith("978"):
                cp = '97150'   
            elif lignetab[1].startswith("986"):
                cp = '98600' 
            elif lignetab[1].startswith("988"):
                cp = '98852'                                                                 
            if len(lignetab)==7  :
                Cligne = 'insert into festivals values (\'' + lignetab[0] + '\',\'' + cp  + '\',' + lignetab[5] + ',' + lignetab[6] + ',\'' + lignetab[3] + '\',\'' + lignetab[4] + '\',\'' + lignetab[2] +'\')'
            else :
                Cligne = 'insert into festivals values (\'' + lignetab[0] + '\',\'' + cp + '\',' + lignetab[6] + ',' + lignetab[7] + ',\'' + lignetab[3] + '\',\'' + lignetab[4] + '\',\'' + lignetab[2] + '\')'
            print(Cligne)    
            try :   
                cursor.execute(Cligne)
            except :
                print("bad")
                except1.append(Cligne)
            v = v+1
                    
            if (v == 2000):
                    connection.commit()
                    cursor.close()
                    connection.close()
                    dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
                    connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
                    cursor = connection.cursor()
                    v = 0
                    print(i)
        i = i + 1
connection.commit()
cursor.close()
connection.close()
# Out:
# 98713
# insert into festivals values ('Lire en Polynésie','98735',-17.557169899999998,-149.55551545,'http://www.lireenpolynesie.com/','Livre','PAPEETE')
# 98713
# insert into festivals values ('Hura Tapairu','98735',-17.557169899999998,-149.55551545,'https://www.huratapairu.com/fr/accueil/','Spectacle vivant','PAPEETE')
# 98713
# insert into festivals values ('Ono U','98735',-17.557169899999998,-149.55551545,'non renseigne','Arts visuels','PAPEETE')
# 98800
# insert into festivals values ('Salon international du livre océanien','98852',-22.336743142768142,166.40832792951736,'non renseigne','Livre','NOUMEA')
# 98713
# insert into festivals values ('Festival internationale du film documentaire océanien - FIFO','98735',-17.557169899999998,-149.55551545,'https://www.fifotahiti.com/','Cinéma','PAPEETE')
# 98880
# insert into festivals values ('Festival de Cinéma de La Foa','98852',-21.747395748645,165.87161042858867,'https://www.festivalcinemalafoa.nc/','Cinéma','LA_FOA')
# 98713
# ...

# %% [markdown]
# UPADATE avec frequentation-des-musees-de-france.csv

# %%
import csv
utilisateur :str = ""
mot_de_passe : str = ""
adresse_IP : str = ""
port : int  = 1521
sid : str = ""

dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
cursor = connection.cursor()
i : int = 0
v : int = 0
except1 : list = []
except2 : list = []
#on a juste de changer le nom du fichier pour un ajouter un nouveau
with open('./frequentation-des-musees-de-france.csv', 'r', encoding='utf-8') as fichier:
    reader = csv.reader(fichier, delimiter=',', quotechar='"')
    for lignetab in reader:
        if i > 0 :
            ligneUPT = 'UPDATE musee SET entre_payant='+lignetab[2]+',entre_gratuit='+lignetab[3]+',entre_total='+lignetab[4]+' WHERE LATTI=ROUND('+lignetab[5]+',8) and longi=ROUND('+lignetab[6]+',8)'
            print(ligneUPT)
            try :   
                cursor.execute(ligneUPT)
            except :
                print("bad")
                except1.append(ligneUPT)
            v = v+1
                    
            if (v == 2000):
                    connection.commit()
                    cursor.close()
                    connection.close()
                    dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
                    connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
                    cursor = connection.cursor()
                    v = 0
                    print(i)
        i = i + 1
connection.commit()
cursor.close()
connection.close()
# Out:
# UPDATE musee SET entre_payant=6635.0,entre_gratuit=1347.0,entre_total=7982.0 WHERE LATTI=ROUND(47.863791,8) and longi=ROUND( 4.574632,8)
# UPDATE musee SET entre_payant=1692.0,entre_gratuit=196.0,entre_total=1888.0 WHERE LATTI=ROUND(47.02097,8) and longi=ROUND( 4.839393,8)
# UPDATE musee SET entre_payant=0.0,entre_gratuit=415.0,entre_total=415.0 WHERE LATTI=ROUND(47.190963,8) and longi=ROUND( 5.383768,8)
# UPDATE musee SET entre_payant=38846.0,entre_gratuit=7897.0,entre_total=46743.0 WHERE LATTI=ROUND(47.536592,8) and longi=ROUND( 4.469595,8)
# UPDATE musee SET entre_payant=5709.0,entre_gratuit=3209.0,entre_total=8918.0 WHERE LATTI=ROUND(45.990936,8) and longi=ROUND( 4.721527,8)
# UPDATE musee SET entre_payant=1336.0,entre_gratuit=718.0,entre_total=2054.0 WHERE LATTI=ROUND(45.895037,8) and longi=ROUND( 3.116254,8)
# UPDATE musee SET entre_payant=2553.0,entre_gratuit=6888.0,entre_total=9441.0 WHERE LATTI=ROUND(45.774229,8) and longi=ROUND( 3.0869,8)
# ...

# %% [markdown]
#     Insert / Update OKculturecheznous

# %%
import csv
utilisateur :str = ""
mot_de_passe : str = ""
adresse_IP : str = ""
port : int  = 1521
sid : str = ""

dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
cursor = connection.cursor()
i : int = 0
v : int = 0
except1 : list = []
except2 : list = []
#on a juste de changer le nom du fichier pour un ajouter un nouveau
with open('./OKculturecheznous.csv', 'r', encoding='utf-8') as fichier:
    reader = csv.reader(fichier, delimiter=',', quotechar='"')
    for lignetab in reader:
        if i > 0 :
            codepo = df[df["Commune"].str.upper() == lignetab[2].replace("_"," ")]["Code Postal"]
            if codepo.empty == False:
                cp = codepo.iloc[0]
            elif df[df["Code INSEE"].str.upper() == lignetab[1]]["Code Postal"].empty == False :
                cp = df[df["Code INSEE"].str.upper() == lignetab[1]]["Code Postal"].iloc[0]
            elif df[df["Code Postal"].str.upper() == lignetab[1]]["Code Postal"].empty == False :
                cp=df[df["Code Postal"].str.upper() == lignetab[1]]["Code Postal"].iloc[0]
            elif lignetab[3].startswith("75"):
                cp = '75001'
            cp = cp.split('/')[0]
            Cligne = ''
            if lignetab[3] in ('Archives') :
                Cligne = 'insert into Archives values (\'Archives\',\''+lignetab[0].replace("'"," ")+'\',NULL,\''+cp+'\',\''+lignetab[5].replace("'"," ")+'\',\''+lignetab[4].replace("'"," ")+'\','+lignetab[6]+','+lignetab[7] + ',NULL,\'' + lignetab[2].replace("'"," ") + '\')'
            elif lignetab[3] in ('Archeologie','Art','Arts décoratif','Bande dessinée','Histoire','Mode','Musées','Photographie','Sciences de la nature','Sculpture') :
                Cligne = 'insert into Musee values (\''+lignetab[0].replace("'"," ")+'\',\''+cp+'\',NULL,\''+lignetab[3].replace("'"," ")+'\','+lignetab[6]+','+lignetab[7]+',\''+lignetab[4].replace("'"," ") + '\',\'' + lignetab[5].replace("'"," ") + '\',\'Musée\',NULL,\''+ lignetab[2].replace("'"," ")+'\')'
            elif lignetab[3] in ('Cinéma') :
                Cligne = 'insert into Cinema values (\'Cinéma\',\''+lignetab[0].replace("'"," ")+'\',\''+cp+'\',\''+lignetab[2].replace("'"," ")+'\',\'Cinéma\',NULL,NULL,NULL,'+lignetab[6].replace("'"," ")+','+lignetab[7].replace("'"," ")+',\''+lignetab[5].replace("'"," ") + '\',\'' + lignetab[4].replace("'"," ") + '\',NULL)'
            elif lignetab[3] in ('Danse','Musique','Théâtre et Spectacles') :
                Cligne = 'insert into Theatre values (\'Theatre\',\''+lignetab[3].replace("'"," ")+'\',\''+lignetab[0].replace("'"," ")+'\',NULL,'+lignetab[6]+','+lignetab[7]+',NULL,\''+lignetab[2].replace("'"," ")+'\','+cp+',NULL,\''+lignetab[5].replace("'"," ") + '\',\'' + lignetab[4].replace("'"," ") + '\')'                
            try :   
                cursor.execute(Cligne)
            except :
                if lignetab[3] in ('Archeologie','Art','Arts décoratif','Bande dessinée','Histoire','Mode','Musées','Photographie','Sciences de la nature','Sculpture') :    
                    try :
                        CligneUPT = 'UPDATE Musee SET "Public" = \''+lignetab[4].replace("'"," ")+'\', ORGANISME = \''+lignetab[5].replace("'"," ")+'\', "Type"=\''+lignetab[3].replace("'"," ")+'\' WHERE Latti = 48.833194 and Longi= 2.378216'
                        cursor.execute(CligneUPT)
                    except :
                        print(CligneUPT)
                        print("BADupdate")
                        except2.append(CligneUPT)                  
                else :
                    print(Cligne)
                    print("BAD")
                    except1.append(Cligne)
            v = v+1
                
            if (v == 2000):
                connection.commit()
                cursor.close()
                connection.close()
                dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
                connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
                cursor = connection.cursor()
                v = 0
                print(i)
        i = i + 1
connection.commit()
cursor.close()
connection.close()

# %% [markdown]
# Insert liste-officielle-musees.csv

# %%
import csv
utilisateur :str = ""
mot_de_passe : str = ""
adresse_IP : str = ""
port : int  = 1521
sid : str = ""

dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
cursor = connection.cursor()
i : int = 0
v : int = 0
except1 : list = []
#on a juste de changer le nom du fichier pour un ajouter un nouveau
with open('./OKOK-liste-officielle-musees.csv', 'r', encoding='utf-8') as fichier:
    reader = csv.reader(fichier, delimiter=',', quotechar='"')
    for lignetab in reader:
            if i > 0 :
                Cligne = 'insert into Musee values (\''+ lignetab[1].replace("'"," ") + '\',\'' + lignetab[2] + '\',\''+ lignetab[3].replace("'"," ") + '\',NULL, ' + lignetab[4]  + ',' + lignetab[5] + ',NULL,NULL,NULL,NULL,\',' + lignetab[0].replace("'"," ").replace(",","")  + '\')' 
                try :   
                    cursor.execute(Cligne)
                    print(Cligne)
                except cx_Oracle.IntegrityError as e:
                    if 'ORA-00001' in str(e):
                        print("Duplication détectée, insertion ignorée")
                    else:
                        print("Erreur d'intégrité :", e)
                        except1.append(Cligne)
                v = v+1
                
                if (v == 2000):
                    connection.commit()
                    cursor.close()
                    connection.close()
                    dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
                    connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
                    cursor = connection.cursor()
                    v = 0
                    print(i)
            i = i + 1
connection.commit()
cursor.close()
connection.close()

# %% [markdown]
# Insert musees-de-france-base-museofile

# %%
import csv
utilisateur :str = ""
mot_de_passe : str = ""
adresse_IP : str = ""
port : int  = 1521
sid : str = ""

dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
cursor = connection.cursor()
i : int = 0
v : int = 0
except1 : list = []
#on a juste de changer le nom du fichier pour un ajouter un nouveau
with open('./OKOK_musees-de-france-base-museofile.csv', 'r', encoding='utf-8') as fichier:
    reader = csv.reader(fichier, delimiter=',', quotechar='"')
    for lignetab in reader:
        if i>0 :
            com = lignetab[4].upper()
            cp = lignetab[3]
            codepo = df[df["Commune"].str.upper() == com.replace("_"," ")]["Code Postal"]
            if codepo.empty == False:
                cp = codepo.iloc[0]
            elif df[df["Code INSEE"].str.upper() == lignetab[3]]["Code Postal"].empty == False :
                cp = df[df["Code INSEE"].str.upper() == lignetab[3]]["Code Postal"].iloc[0]
            elif df[df["Code Postal"].str.upper() == lignetab[3]]["Code Postal"].empty == False :
                cp=df[df["Code Postal"].str.upper() == lignetab[3]]["Code Postal"].iloc[0]
            elif lignetab[3].startswith("75"):
                cp = '75001'
            Cligne = 'insert into Musee values (\''+ lignetab[2].replace("'"," ") + '\',\'' + cp.split('/')[0] + '\',\''+ lignetab[5].replace("'"," ") + '\',\''+ lignetab[6].replace("'"," ") + '\', ' + lignetab[7]  + ',' + lignetab[8] + ',NULL,NULL,NULL,NULL,\',' + lignetab[4].replace("'"," ") + '\')' 
            try :   
                cursor.execute(Cligne)
                print(Cligne)
            except  :
                print(Cligne)
                except1.append(Cligne)
                print("bad")
            v = v+1
            
            if (v == 2000):
                connection.commit()
                cursor.close()
                connection.close()
                dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
                connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
                cursor = connection.cursor()
                v = 0
                print(i)
        i = i + 1
connection.commit()
cursor.close()
connection.close()

# %% [markdown]
# Insert/Update base-des-lieux-et-des-equipements-culturels.csv

# %%
import csv
utilisateur :str = ""
mot_de_passe : str = ""
adresse_IP : str = ""
port : int  = 1521
sid : str = ""

dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
cursor = connection.cursor()
i : int = 0
v : int = 0
except1 : list = []
except2 : list = []
#on a juste de changer le nom du fichier pour un ajouter un nouveau
with open('./OK-base-des-lieux-et-des-equipements-culturels.csv', 'r', encoding='utf-8') as fichier:
    reader = csv.reader(fichier, delimiter=',', quotechar='"')
    for lignetab in reader:
        if i > 0 :
            sous_domaine = lignetab[3]
            domaine = lignetab[5]
            lignetab[4] = str(int(float(lignetab[4])))
            lignetab[1] = lignetab[1].replace('_',' ')
            if domaine=='Cinéma':
                CligneUPT = 'UPDATE Cinema SET fauteuil ='+ lignetab[10] + ',' + 'ecran =' + lignetab[9] + ', GCD=\''+lignetab[6]+'\' WHERE upper(NOM) = upper(\'' + lignetab[1] + '\') and CP= LPAD(\'' + lignetab[4] +'\', 5, \'0\')'
            elif domaine=='Arts du spectacle':
                CligneUPT = 'UPDATE Theatre SET JAUGE =\'' + lignetab[12] + '\', GCD=\''+lignetab[6]+'\' WHERE upper(NOM) = upper(\'' + lignetab[1] + '\') and CP= LPAD(\'' + lignetab[4] +'\', 5, \'0\')'
            elif domaine in ('Lecture publique'):
                CligneUPT = 'UPDATE bibliotheque SET GCD=\''+lignetab[6]+'\' WHERE upper(NOM) = upper(\'' + lignetab[1] + '\') and CP= LPAD(\'' + lignetab[4] +'\', 5, \'0\')'
            try :   
                cursor.execute(Cligne)
            except :
                        domaine=lignetab[5] 
                        sous_domaine=lignetab[3] 
                        Cligne = ''
                        lignetab[4] = str(int(float(lignetab[4])))
                        lignetab[1] = lignetab[1].replace('_',' ')
                        if domaine=='Cinéma':
                            Cligne = 'insert into CINEMA values (\''+domaine+'\',\''+lignetab[1]+'\',LPAD(\''+lignetab[4]+'\', 5, \'0\'),\''+lignetab[2]+'\',\''+sous_domaine+'\','+lignetab[9]+','+lignetab[10]+',\''+lignetab[6]+'\','+lignetab[8]+','+lignetab[7]+',Null,Null,Null)'            
                        elif domaine=='Archives':
                            Cligne = 'insert into ARCHIVES values (\''+domaine+'\',\''+lignetab[1]+'\',\''+lignetab[6]+'\',LPAD(\''+lignetab[4]+'\', 5, \'0\'),Null,Null,'+lignetab[8]+','+lignetab[7]+',\''+sous_domaine+'\',\''+lignetab[2]+'\')'
                        elif (domaine=='Arts du spectacle') or (domaine=="Éducation et formation" and sous_domaine in ("Danse,Musique,Theatre","Musique,Danse,Théâtre")) :
                            if lignetab[12] == '' :
                                    lignetab[12]= 'Null'
                            Cligne = 'insert into THEATRE values (\'Theatre\',\''+sous_domaine+'\',\''+lignetab[1] +'\',Null,'+lignetab[8] +','+lignetab[7]+','+lignetab[12]+',\''+lignetab[2]+'\',LPAD(\''+lignetab[4]+'\', 5, \'0\'),\''+lignetab[6]+'\',Null,Null )'
                        elif domaine=='Livre et presse':
                            Cligne = 'insert into BIBLIOTHEQUE values (LPAD(\''+lignetab[4]+'\', 5, \'0\'),Null,\''+lignetab[1]+'\',\''+lignetab[2]+'\',Null,\''+sous_domaine+'\',\'LIBRAIRIE\',Null,\''+lignetab[6]+'\',Null,Null,Null,'+lignetab[8]+','+lignetab[7]+')'
                            print(Cligne)
                        try :
                            cursor.execute(Cligne)
                        except :
                            if(Cligne != '') :
                                print(Cligne)
                                print("BADupdate")
                                except2.append(Cligne)                  
            v = v+1
                
            if (v == 2000):
                connection.commit()
                cursor.close()
                connection.close()
                dsn = cx_Oracle.makedsn(adresse_IP, port, sid)
                connection = cx_Oracle.connect(utilisateur, mot_de_passe, dsn)
                cursor = connection.cursor()
                v = 0
                print(i)
        i = i + 1
connection.commit()
cursor.close()
connection.close()
